# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

pprint(api_key)
# Out:
# '37c95f529459c0945afa7610e27fe796'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Perform Weather Check For Loop
# ==============================================

# Create Base URL & Temp Units
base_url = 'http://api.openweathermap.org/data/2.5/weather?q='
units = '&units=imperial'

# Begin Data Log Printout
print("Beginning Data Retrieval")
print("-----------------------------")


# Create/Write CSV File

with open(output_data_file, mode= 'w',newline='') as csv_file:
    fieldnames = ['City','Cloudiness','Country','Date','Humidity','Lat','Lng','Max Temp','Wind Speed']
    writer = csv.DictWriter(csv_file, fieldnames= fieldnames)
    writer.writeheader()
    
    count = 0
    Set = 1

    # Make successive API Calls to Open Weather API and Write them to 'cities.csv' 
    for City in cities:
        params = City + "&APPID=" + api_key + units
        city_data = requests.get(base_url + params).json()
        
        # Exception Handling for cities in the cities list but not in the API database
        try:
            
            print(f"Processing Record {count} of Set {Set} | {City.title()}")
            
            writer.writerow({'City': city_data['name'],'Cloudiness': city_data['clouds']['all'],
                            'Country': city_data['sys']['country'],'Date': city_data['dt'], 
                            'Humidity': city_data['main']['humidity'],'Lat': city_data['coord']['lat'],
                            'Lng': city_data['coord']['lon'],'Max Temp': city_data['main']['temp_max'],
                            'Wind Speed': city_data['wind']['speed']})

            count = count + 1
            if count % 50 == 0:
                Set = Set + 1
                count = 0
            
            
        except:
            
            print(f'Records for "{City.title()}" not found. Skipping...')
            
            
print('----------------------------')
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | Paracatu
# Processing Record 1 of Set 1 | Punta Arenas
# Processing Record 2 of Set 1 | Kupang
# Processing Record 3 of Set 1 | Kodiak
# Processing Record 4 of Set 1 | Yellowknife
# Processing Record 5 of Set 1 | Skagastrond
# Records for "Skagastrond" not found. Skipping...
# Processing Record 5 of Set 1 | San Andres
# Processing Record 6 of Set 1 | Makakilo City
# Processing Record 7 of Set 1 | Busselton
# Processing Record 8 of Set 1 | Georgetown
# Processing Record 9 of Set 1 | Lebu
# Processing Record 10 of Set 1 | Ananindeua
# Processing Record 11 of Set 1 | Hermanus
# Processing Record 12 of Set 1 | Attawapiskat
# Records for "Attawapiskat" not found. Skipping...
# Processing Record 12 of Set 1 | Seoul
# Processing Record 13 of Set 1 | Asau
# Records for "Asau" not found. Skipping...
# Processing Record 13 of Set 1 | Lavrentiya
# Processing Record 14 of Set 1 | Taolanaro
# Records for "Taolanaro" not found. Skipping...
# Processing Record 14 of Set 1 | Puerto Ayora
# Processing Record 15 of Set 1 | Butaritari
# Processing Record 16 of Set 1 | Conde
# Processing Record 17 of Set 1 | Dikson
# Processing Record 18 of Set 1 | Kavieng
# Processing Record 19 of Set 1 | Qaanaaq
# Processing Record 20 of Set 1 | Klyuchi
# Processing Record 21 of Set 1 | Adrar
# Processing Record 22 of Set 1 | Vaini
# Processing Record 23 of Set 1 | Arraial Do Cabo
# Processing Record 24 of Set 1 | Atasu
# Processing Record 25 of Set 1 | Hilo
# Processing Record 26 of Set 1 | Ushuaia
# Processing Record 27 of Set 1 | Houston
# Processing Record 28 of Set 1 | Upernavik
# Processing Record 29 of Set 1 | Bengkalis
# Records for "Bengkalis" not found. Skipping...
# Processing Record 1 of Set 4 | Chokurdakh
# Processing Record 2 of Set 4 | Toliary
# Records for "Toliary" not found. Skipping...
# Processing Record 2 of Set 4 | Sentyabrskiy
# Records for "Sentyabrskiy" not found. Skipping...
# Processing Record 2 of Set 4 | Pilar
# Processing Record 3 of Set 4 | Bluff
# Processing Record 4 of Set 4 | Barra Do Garcas
# Processing Record 5 of Set 4 | Bonavista
# Processing Record 6 of Set 4 | Norman Wells
# Processing Record 7 of Set 4 | Saint-Philippe
# Processing Record 8 of Set 4 | Faanui
# Processing Record 9 of Set 4 | Clarence Town
# Processing Record 10 of Set 4 | Palabuhanratu
# Records for "Palabuhanratu" not found. Skipping...
# Processing Record 10 of Set 4 | Azad Shahr
# Records for "Azad Shahr" not found. Skipping...
# Processing Record 10 of Set 4 | Ribeira Grande
# Processing Record 11 of Set 4 | Poum
# Processing Record 12 of Set 4 | Pombia
# Processing Record 13 of Set 4 | Mahebourg
# Processing Record 14 of Set 4 | Yelan-Koleno
# Processing Record 15 of Set 4 | Moerai
# Processing Record 16 of Set 4 | Arcata
# Processing Record 17 of Set 4 | Tessalit
# Processing Record 18 of Set 4 | Ibi
# Processing Record 19 of Set 4 | Douglas
# Processing Record 20 of Set 4 | Arlit
# Processing Record 21 of Set 4 | Ponta Do Sol
# Processing Record 22 of Set 4 | Provideniya
# Processing Record 23 of Set 4 | Porto Novo
# Processing Record 24 of Set 4 | Klaksvik
# Processing Record 25 of Set 4 | Bridgton
# Processing Record 26 of Set 4 | Kaset Sombun
# Processing Record 27 of Set 4 | Ciudad Del Maiz
# Processing Record 28 of Set 4 | Nalut
# Processing Record 29 of Set 4 | Tabou
# Processing Record 30 of Set 4 | Weiser
# Processing Record 31 of Set 4 | Camana
# Records for "Camana" not found. Skipping...
# Processing Record 31 of Set 4 | Tuatapere
# Processing Record 32 of Set 4 | Yulara
# Processing Record 33 of Set 4 | Varzea Grande
# Processing Record 34 of Set 4 | Namatanai
# Processing Record 35 of Set 4 | Takob
# Records for "Takob" not found. Skipping...
# Processing Record 35 of Set 4 | Bud
# Processing Record 36 of Set 4 | Moba
# Processing Record 37 of Set 4 | Fortuna
# Processing Record 38 of Set 4 | Lazaro Cardenas
# Processing Record 39 of Set 4 | Wagga Wagga
# Processing Record 40 of Set 4 | Sand Springs
# Processing Record 41 of Set 4 | Oliveira Dos Brejinhos
# Processing Record 42 of Set 4 | Codrington
# Processing Record 43 of Set 4 | Yol
# Processing Record 44 of Set 4 | Morrope
# Processing Record 45 of Set 4 | Mys Shmidta
# Records for "Mys Shmidta" not found. Skipping...
# Processing Record 45 of Set 4 | Chifeng
# Processing Record 46 of Set 4 | Geraldton
# Processing Record 47 of Set 4 | Bay City
# Processing Record 48 of Set 4 | Grindavik
# Processing Record 49 of Set 4 | Brigantine
# Processing Record 0 of Set 5 | Ust-Karsk
# Processing Record 1 of Set 5 | Gondanglegi
# Processing Record 2 of Set 5 | Narsaq
# Processing Record 3 of Set 5 | Anloga
# Processing Record 4 of Set 5 | Kununurra
# Processing Record 5 of Set 5 | Saleaula
# Records for "Saleaula" not found. Skipping...
# Processing Record 5 of Set 5 | Edeia
# Processing Record 6 of Set 5 | Meulaboh
# Processing Record 7 of Set 5 | Amderma
# Records for "Amderma" not found. Skipping...
# Processing Record 7 of Set 5 | Saldanha
# Processing Record 8 of Set 5 | Beringovskiy
# Processing Record 9 of Set 5 | Kruisfontein
# Processing Record 10 of Set 5 | Peshkovo
# Processing Record 11 of Set 5 | Belushya Guba
# Records for "Belushya Guba" not found. Skipping...
# Processing Record 11 of Set 5 | Chuy
# Processing Record 12 of Set 5 | The Valley
# Processing Record 13 of Set 5 | Olafsvik
# Records for "Olafsvik" not found. Skipping...
# Processing Record 13 of Set 5 | Esperance
# Processing Record 14 of Set 5 | Alotau
# Records for "Alotau" not found. Skipping...
# Processing Record 14 of Set 5 | Verkhoyansk
# Processing Record 15 of Set 5 | Praia
# Processing Record 16 of Set 5 | Achinsk
# Processing Record 17 of Set 5 | Ust-Nera
# Processing Record 18 of Set 5 | Vitoria Do Mearim
# Processing Record 19 of Set 5 | Hienghene
# Processing Record 20 of Set 5 | Srednekolymsk
# Processing Record 21 of Set 5 | Port Elizabeth
# Processing Record 22 of Set 5 | Bonfim
# Processing Record 23 of Set 5 | Manzhouli
# Processing Record 24 of Set 5 | Purranque
# Processing Record 25 of Set 5 | Tumannyy
# Records for "Tumannyy" not found. Skipping...
# Processing Record 25 of Set 5 | Alice Springs
# Processing Record 26 of Set 5 | Sabang
# Processing Record 27 of Set 5 | Acajutla
# Processing Record 28 of Set 5 | Aflu
# Records for "Aflu" not found. Skipping...
# Processing Record 28 of Set 5 | Mezen
# Processing Record 29 of Set 5 | Itarema
# Processing Record 30 of Set 5 | Nizhneyansk
# Records for "Nizhneyansk" not found. Skipping...
# Processing Record 30 of Set 5 | Sola
# Processing Record 31 of Set 5 | Vaitupu
# Records for "Vaitupu" not found. Skipping...
# Processing Record 31 of Set 5 | Beisfjord
# Processing Record 32 of Set 5 | Yuli
# Processing Record 33 of Set 5 | Fallon
# Processing Record 34 of Set 5 | Labuhan
# Processing Record 35 of Set 5 | Axim
# Processing Record 36 of Set 5 | Mayya
# Processing Record 37 of Set 5 | Raga
# Records for "Raga" not found. Skipping...
# Processing Record 37 of Set 5 | Letlhakane
# Processing Record 38 of Set 5 | Mangrol
# Processing Record 39 of Set 5 | Tiznit
# Processing Record 40 of Set 5 | Fort Nelson
# Processing Record 41 of Set 5 | Muros
# Processing Record 42 of Set 5 | Puerto Armuelles
# Processing Record 43 of Set 5 | Dzerzhinsk
# Processing Record 44 of Set 5 | New Norfolk
# Processing Record 45 of Set 5 | Bethel
# Processing Record 46 of Set 5 | Saint-Georges
# Processing Record 47 of Set 5 | Tura
# Processing Record 48 of Set 5 | Tutla
# Records for "Tutla" not found. Skipping...
# Processing Record 48 of Set 5 | Calatayud
# Processing Record 49 of Set 5 | Hofn
# Processing Record 0 of Set 6 | Chegem
# Processing Record 1 of Set 6 | Arivonimamo
# Processing Record 2 of Set 6 | Pacific Grove
# Processing Record 3 of Set 6 | College
# Processing Record 4 of Set 6 | Nantucket
# Processing Record 5 of Set 6 | Cayenne
# Processing Record 6 of Set 6 | Rio Grande
# Processing Record 7 of Set 6 | Taoudenni
# Processing Record 8 of Set 6 | Dingle
# Processing Record 9 of Set 6 | Mount Isa
# Processing Record 10 of Set 6 | Mocuba
# Processing Record 11 of Set 6 | Brainerd
# Processing Record 12 of Set 6 | Komsomolskiy
# Processing Record 13 of Set 6 | Lushunkou
# Records for "Lushunkou" not found. Skipping...
# Processing Record 13 of Set 6 | Buala
# Processing Record 14 of Set 6 | Kieta
# Processing Record 15 of Set 6 | Dobsina
# Processing Record 16 of Set 6 | Talaya
# Processing Record 17 of Set 6 | Vanimo
# Processing Record 18 of Set 6 | Helong
# Processing Record 19 of Set 6 | Mana
# Processing Record 20 of Set 6 | Bay Roberts
# Processing Record 21 of Set 6 | Mwingi
# Processing Record 22 of Set 6 | Kommunisticheskiy
# Processing Record 23 of Set 6 | Te Anau
# Processing Record 24 of Set 6 | Hay River
# Processing Record 25 of Set 6 | Teeli
# Processing Record 26 of Set 6 | Bose
# Processing Record 27 of Set 6 | Carutapera
# Processing Record 28 of Set 6 | Garmsar
# Processing Record 29 of Set 6 | Bantry
# Records for "Bantry" not found. Skipping...
# Processing Record 29 of Set 6 | Clyde River
# Processing Record 30 of Set 6 | Ballina
# Processing Record 31 of Set 6 | Maku
# Processing Record 32 of Set 6 | Bulgan
# Processing Record 33 of Set 6 | New Bedford
# Processing Record 34 of Set 6 | Tandil
# Processing Record 35 of Set 6 | Tonota
# Processing Record 36 of Set 6 | Velyka Lepetykha
# Processing Record 37 of Set 6 | Bayshore Gardens
# Processing Record 38 of Set 6 | Erzin
# Processing Record 39 of Set 6 | Putai
# Processing Record 40 of Set 6 | Gawler
# Processing Record 41 of Set 6 | Bengkulu
# Records for "Bengkulu" not found. Skipping...
# Processing Record 41 of Set 6 | Mayo
# Processing Record 42 of Set 6 | Avera
# Processing Record 43 of Set 6 | Hokitika
# Processing Record 44 of Set 6 | Beipiao
# Processing Record 45 of Set 6 | Champerico
# Processing Record 46 of Set 6 | Nanortalik
# Processing Record 47 of Set 6 | Vostok
# Processing Record 48 of Set 6 | Hyeres
# Processing Record 49 of Set 6 | Shenjiamen
# Processing Record 0 of Set 7 | Odweyne
# Records for "Odweyne" not found. Skipping...
# Processing Record 0 of Set 7 | Ordzhonikidze
# Processing Record 1 of Set 7 | Ixtapa
# Processing Record 2 of Set 7 | Praia Da Vitoria
# Processing Record 3 of Set 7 | Merauke
# Processing Record 4 of Set 7 | Alekseyevsk
# Processing Record 5 of Set 7 | Brae
# Processing Record 6 of Set 7 | Rafai
# Processing Record 7 of Set 7 | Laguna
# Processing Record 8 of Set 7 | Savannah Bight
# Processing Record 9 of Set 7 | Qaqortoq
# Processing Record 10 of Set 7 | Mount Gambier
# Processing Record 11 of Set 7 | Severo-Kurilsk
# Processing Record 12 of Set 7 | Caibarien
# Processing Record 13 of Set 7 | Boca Do Acre
# Processing Record 14 of Set 7 | Key West
# Processing Record 15 of Set 7 | Zirgan
# Processing Record 16 of Set 7 | Sandpoint
# Processing Record 17 of Set 7 | Pahrump
# Processing Record 18 of Set 7 | Heze
# Processing Record 44 of Set 9 | Cockburn Town
# Processing Record 45 of Set 9 | Barra Do Bugres
# Processing Record 46 of Set 9 | Lorengau
# Processing Record 47 of Set 9 | Sitka
# Processing Record 48 of Set 9 | Palmerston North
# Processing Record 49 of Set 9 | Kaputa
# Processing Record 0 of Set 10 | Bandarbeyla
# Processing Record 1 of Set 10 | Boljevac
# Processing Record 2 of Set 10 | Makat
# Processing Record 3 of Set 10 | Freeport
# Processing Record 4 of Set 10 | Ukiah
# Processing Record 5 of Set 10 | Roberval
# Processing Record 6 of Set 10 | San Patricio
# Processing Record 7 of Set 10 | Northam
# Processing Record 8 of Set 10 | Hermsdorf
# Processing Record 9 of Set 10 | Dolores
# Processing Record 10 of Set 10 | Henties Bay
# Processing Record 11 of Set 10 | Bathsheba
# Processing Record 12 of Set 10 | Sirnak
# Processing Record 13 of Set 10 | Aitape
# Processing Record 14 of Set 10 | Abu Samrah
# Processing Record 15 of Set 10 | Dangtu
# Processing Record 16 of Set 10 | Kushmurun
# Records for "Kushmurun" not found. Skipping...
# Processing Record 16 of Set 10 | Aswan
# Processing Record 17 of Set 10 | Amurzet
# Processing Record 18 of Set 10 | Bagasara
# Records for "Bagasara" not found. Skipping...
# Processing Record 18 of Set 10 | Massakory
# Processing Record 19 of Set 10 | Alghero
# Processing Record 20 of Set 10 | Mehamn
# Processing Record 21 of Set 10 | Ponta Delgada
# Processing Record 22 of Set 10 | Sassandra
# Processing Record 23 of Set 10 | Cordoba
# Processing Record 24 of Set 10 | Non Sung
# Processing Record 25 of Set 10 | Bredy
# Processing Record 26 of Set 10 | Mrirt
# Records for "Mrirt" not found. Skipping...
# Processing Record 26 of Set 10 | Westminster
# Processing Record 27 of Set 10 | Quatre Cocos
# Processing Record 28 of Set 10 | Port Blair
# Processing Record 29 of Set 10 | Gayeri
# Processing Record 30 of Set 10 | Saint-Joseph
# Processing Record 31 of Set 10 | Lucea
# Processing Record 32 of Set 10 | Ugoofaaru
# Processing Record 33 of Set 10 | Touros
# Processing Record 34 of Set 10 | San Francisco
# Processing Record 35 of Set 10 | Termoli
# Processing Record 36 of Set 10 | Warqla
# Records for "Warqla" not found. Skipping...
# Processing Record 36 of Set 10 | Pasewalk
# Processing Record 37 of Set 10 | Mandalgovi
# Processing Record 38 of Set 10 | Turukhansk
# Processing Record 39 of Set 10 | Strezhevoy
# Processing Record 40 of Set 10 | Nyrob
# Processing Record 41 of Set 10 | Lakes Entrance
# Processing Record 42 of Set 10 | Dombas
# Processing Record 43 of Set 10 | Kyshtovka
# Processing Record 44 of Set 10 | Mogadishu
# Processing Record 45 of Set 10 | San Quintin
# Processing Record 46 of Set 10 | Bolungarvik
# Records for "Bolungarvik" not found. Skipping...
# Processing Record 46 of Set 10 | Unnao
# Processing Record 47 of Set 10 | Padang
# Processing Record 48 of Set 10 | Vrangel
# Processing Record 49 of Set 10 | Batagay-Alyta
# Processing Record 0 of Set 11 | Usinsk
# Processing Record 1 of Set 11 | Kota Belud
# Processing Record 2 of Set 11 | Bushehr
# Processing Record 3 of Set 11 | Kuusamo
# Processing Record 4 of Set 11 | Miasskoye
# Processing Record 5 of Set 11 | Bull Savanna
# Processing Record 6 of Set 11 | Seoni
# Processing Record 7 of Set 11 | Paris
# Processing Record 8 of Set 11 | Alugan
# Processing Record 9 of Set 11 | Khani
# Processing Record 10 of Set 11 | Atar
# Processing Record 11 of Set 11 | Pokhara
# Processing Record 12 of Set 11 | Coquimbo
# Processing Record 13 of Set 11 | Palmer
# Processing Record 14 of Set 11 | Sibolga
# Processing Record 15 of Set 11 | Mangochi
# Processing Record 16 of Set 11 | Vigia Del Fuerte
# Processing Record 17 of Set 11 | Teguise
# Processing Record 18 of Set 11 | Burnie
# Processing Record 19 of Set 11 | Tarumovka
# Processing Record 20 of Set 11 | Nador
# Processing Record 21 of Set 11 | Labuan
# Processing Record 22 of Set 11 | Araras
# Processing Record 23 of Set 11 | Tarauaca
# Processing Record 24 of Set 11 | Mukhen
# Processing Record 25 of Set 11 | Kambove
# Processing Record 26 of Set 11 | Oksfjord
# Processing Record 27 of Set 11 | Salym
# Processing Record 28 of Set 11 | Bilibino
# Processing Record 29 of Set 11 | Nachingwea
# Processing Record 30 of Set 11 | Qasigiannguit
# Processing Record 31 of Set 11 | Malindi
# Processing Record 32 of Set 11 | Verkhnyaya Inta
# Processing Record 33 of Set 11 | Dicabisagan
# Processing Record 34 of Set 11 | Stepnyak
# Processing Record 35 of Set 11 | Iquitos
# Processing Record 36 of Set 11 | Pedernales
# Processing Record 37 of Set 11 | Nhulunbuy
# Processing Record 38 of Set 11 | Rungata
# Records for "Rungata" not found. Skipping...
# Processing Record 38 of Set 11 | Scarborough
# Processing Record 39 of Set 11 | Sedro-Woolley
# Processing Record 40 of Set 11 | Virginia Beach
# Processing Record 41 of Set 11 | Lusambo
# Processing Record 42 of Set 11 | Vasarosnameny
# Processing Record 43 of Set 11 | Naze
# Processing Record 44 of Set 11 | Kashi
# Records for "Kashi" not found. Skipping...
# Processing Record 44 of Set 11 | Westport
# Processing Record 45 of Set 11 | Marfino
# Processing Record 46 of Set 11 | Mormugao
# Records for "Mormugao" not found. Skipping...
# Processing Record 46 of Set 11 | Flinders
# Processing Record 47 of Set 11 | Aketi
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
# Test Call Code
# =====================

# '''query_url = base_url + City + '&APPID=' + api_key + units

# test_call = requests.get(base_url + "Raleigh" + '&APPID=' + api_key + units).json()

# pprint(test_call)
# print('')
# print('----------')
# print(f"Cloudiness in Raleigh is {test_call['clouds']['all']}")    
    
        
        
# print(cities[-1])''';

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Read the CSV with Pandas to Create a DataFrame

city_weather_df = pd.read_csv("cities.csv")
city_weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Paracatu          86      BR  1571361642        49 -17.22  -46.87
# 1  Punta Arenas          75      CL  1571361642        65 -53.16  -70.91
# 2        Kupang          20      ID  1571361642        58 -10.16  123.60
# 3        Kodiak           1      US  1571361643        62  39.95  -94.76
# 4   Yellowknife          90      CA  1571361643        90  62.45 -114.38
#
#    Max Temp  Wind Speed
# 0     78.86        4.09
# 1     44.60        6.93
# 2     84.20        8.05
# 3     57.99        9.17
# 4     34.00        8.05

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plot Latitude vs. Temperature
# =============================

# Change the Figure Size
fig, ax = plt.subplots(figsize=(10,10))

# Create Variables for the Series
lat = city_weather_df["Lat"]
temp = city_weather_df["Max Temp"]

# Set y limits
ax.set_ylim(lat.min() - 20, lat.max() + 20)

# Set y ticks
ax.set_yticks([round(x) for x in np.arange(lat.min() - 20, lat.max() + 20, step= 10)] + [0])

# Create the x & y labels
ax.set_ylabel("City Latitude", size= "x-large")
ax.set_xlabel("City Temperatures", size= "x-large")

# Create the Title
ax.set_title("Temperature vs. City Latitude", size= 20)

# Create Equator Horizontal Line
ax.axhline(y=0, color= 'gray')

# Plot the Series
ax.scatter(temp, lat, color= "b", marker="o", s= 50, alpha=.5)

plt.show()

fig.savefig("../Images/Temperature vs. City Latitude.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot Latitude vs. Humidity
# =============================

# Change the Figure Size
fig, ax = plt.subplots(figsize=(10,10))

# Create Variables for the Series
lat = city_weather_df["Lat"]
temp = city_weather_df["Humidity"]

# Set y limits
ax.set_ylim(lat.min() - 20, lat.max() + 20)

# Set y ticks
ax.set_yticks([round(x) for x in np.arange(lat.min() - 20, lat.max() + 20, step= 10)] + [0])

# Create the Title
ax.set_title("Humidity vs. City Latitude", size= 20)

# Create Equator Horizontal Line
ax.axhline(y=0, color= 'gray')

# Create the x & y labels
ax.set_ylabel("City Latitude", size= "x-large")
ax.set_xlabel("City Humidity", size= "x-large")

# Plot the Series
ax.scatter(temp, lat, color= "orange", marker="o", s= 50, alpha=.5)

plt.show()

fig.savefig("../Images/Humidity vs. City Latitude.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot Latitude vs. Cloudiness
# =============================

# Change the Figure Size
fig, ax = plt.subplots(figsize=(10,10))

# Create Variables for the Series
lat = city_weather_df["Lat"]
temp = city_weather_df["Cloudiness"]

# Set y limits
ax.set_ylim(lat.min() - 20, lat.max() + 20)

# Set y ticks
ax.set_yticks([round(x) for x in np.arange(lat.min() - 20, lat.max() + 20, step= 10)] + [0])

# Create the x & y labels
ax.set_ylabel("City Latitude", size= "x-large")
ax.set_xlabel("City Cloudiness", size= "x-large")

# Create the Title
ax.set_title("Cloudiness vs. City Latitude", size= 20)

# Create Equator Horizontal Line
ax.axhline(y=0, color= 'gray')

# Plot the Series
ax.scatter(temp, lat, color= "g", marker="o", s= 50, alpha=.5)

plt.show()

fig.savefig("../Images/Cloudiness vs. City Latitude.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot Latitude vs. Wind Speed
# =============================

# Change the Figure Size
fig, ax = plt.subplots(figsize=(10,10))

# Create Variables for the Series
lat = city_weather_df["Lat"]
temp = city_weather_df["Wind Speed"]

# Set y limits
ax.set_ylim(lat.min() - 20, lat.max() + 20)

# Set y ticks
ax.set_yticks([round(x) for x in np.arange(lat.min() - 20, lat.max() + 20, step= 10)] + [0])

# Create the x & y labels
ax.set_ylabel("City Latitude", size= "x-large")
ax.set_xlabel("City Wind Speed", size= "x-large")

# Create the Title
ax.set_title("Wind Speed vs. City Latitude", size= 20)

# Create Equator Horizontal Line
ax.axhline(y=0, color= 'gray')

# Plot the Series
ax.scatter(temp, lat, color= "r", marker="o", s= 50, alpha=.5)

plt.show()

fig.savefig("../Images/Wind Speed vs. City Latitude.png")
